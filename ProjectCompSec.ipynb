# 995810  Vladivostok  0.030762 -0.092773 -0.109375  0.466797  0.223633
# 995965  Vladimirova -0.001518  0.040771 -0.015015  0.011536  0.020996
# 996000    Vladimira -0.139648  0.024902 -0.048584 -0.057617 -0.017212
# 996359        Vladi  0.245117 -0.008789  0.037598 -0.080078  0.088379
# 997899    VKontakte  0.195312 -0.185547 -0.023071  0.099609 -0.123047
#
#            dim_6     dim_7     dim_8     dim_9  ...   dim_291   dim_292  \
# ...

# %%
password_df.to_csv('password_to_vectors.csv')

# %% [markdown]
# # Get Vectors by Ready File

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

password_df = pd.read_csv('/content/drive/MyDrive/Passwords_To_Vectors/password_to_vectors.csv', index_col=0)
password_df
# Out:
#                word     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 1          password -0.096680  0.151367 -0.138672  0.049316  0.103027
# 3            qwerty -0.077148  0.004822 -0.255859  0.310547  0.028442
# 9            dragon  0.171875  0.170898 -0.061279  0.100586  0.064941
# 11         baseball -0.105469  0.255859  0.253906 -0.031250 -0.285156
# 13         football -0.097656  0.031982  0.257812 -0.041504  0.101562
# ...             ...       ...       ...       ...       ...       ...
# 995810  Vladivostok  0.030762 -0.092773 -0.109375  0.466797  0.223633
# 995965  Vladimirova -0.001518  0.040771 -0.015015  0.011536  0.020996
# 996000    Vladimira -0.139648  0.024902 -0.048584 -0.057617 -0.017212
# 996359        Vladi  0.245117 -0.008789  0.037598 -0.080078  0.088379
# 997899    VKontakte  0.195312 -0.185547 -0.023071  0.099609 -0.123047
#
#            dim_6     dim_7     dim_8     dim_9  ...   dim_291   dim_292  \
# ...

# %% [markdown]
# # Get Results from Vectors

# %%
password_df.loc[:, 'dim_1':'dim_300'].to_numpy()
# Out:
# array([[-0.09667969,  0.15136719, -0.13867188, ..., -0.41992188,
#         -0.33789062,  0.07617188],
#        [-0.07714844,  0.00482178, -0.25585938, ..., -0.04418945,
#         -0.07324219,  0.24023438],
#        [ 0.171875  ,  0.17089844, -0.0612793 , ...,  0.22460938,
#         -0.13574219,  0.09277344],
#        ...,
#        [-0.13964844,  0.02490234, -0.04858398, ...,  0.09423828,
#          0.18164062,  0.07373047],
#        [ 0.24511719, -0.00878906,  0.03759766, ..., -0.22851562,
#          0.06347656,  0.00698853],
#        [ 0.1953125 , -0.18554688, -0.02307129, ..., -0.00952148,
#         -0.04394531,  0.05151367]])

# %%
#########################################################
# Since there is no enough RAM, it could not be runned!!!
#########################################################

###############
# DO NOT RUN!!!
###############

import numpy as np
from sklearn.metrics.pairwise import euclidean_distances

distance_matrix = euclidean_distances(password_df.loc[:, 'dim_1':'dim_300'])
top_k_similar_indexes = np.argsort(distance_matrix, axis=1)[:, :2]

# %%
#########################################################
# Since there is no enough RAM, it could not be runned!!!
#########################################################

###############
# DO NOT RUN!!!
###############

from scipy import spatial

for i in range(20):
  print(password_df.iloc[[list(list(top_k_similar_indexes)[i])[0]]]['word'].values[0] + ' - ' + password_df.iloc[[list(list(top_k_similar_indexes)[i])[1]]]['word'].values[0] 
        + " \t\t " 
        + "-> {0:.2%}".format(1 - spatial.distance.cosine(password_df.loc[:, 'dim_1':'dim_300'].to_numpy()[list(list(top_k_similar_indexes)[i])[0]], password_df.loc[:, 'dim_1':'dim_300'].to_numpy()[list(list(top_k_similar_indexes)[i])[1]])))

# %%
from itertools import combinations

top_n = 20
examined_numbers = 100
for counter in range(top_n):
  print(sorted([ ((wv.similarity(p[0], p[1])), p) for p in combinations(list(password_df[:examined_numbers]['word']), 2)], reverse=True)[counter])
# Out:
# (0.73135483, ('football', 'soccer'))
# (0.7276427, ('thomas', 'anthony'))
# (0.69900966, ('michael', 'anthony'))
# (0.6987349, ('jennifer', 'ashley'))
# (0.69135654, ('andrew', 'robert'))
# (0.69129443, ('michael', 'robert'))
# (0.68684155, ('ashley', 'justin'))
# (0.68504566, ('robert', 'patrick'))
# (0.6790757, ('jennifer', 'samantha'))
# (0.67785484, ('michael', 'thomas'))
# (0.674379, ('robert', 'richard'))
# (0.67418355, ('dallas', 'austin'))
# (0.6728577, ('ashley', 'matthew'))
# (0.6725475, ('andrew', 'richard'))
# (0.67245346, ('michael', 'jackson'))
# (0.6713607, ('asshole', 'fuck'))
# (0.66979665, ('ashley', 'samantha'))
# (0.6697518, ('thomas', 'jackson'))
# (0.66913694, ('thomas', 'george'))
# (0.66908777, ('jennifer', 'andrea'))

# %%
import plotly
import numpy as np
import plotly.graph_objs as go
from sklearn.decomposition import PCA

def display_pca_scatterplot_2D(model, user_input=None, words=None, topn=5, sample=10):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.vocab.keys()), sample)
        else:
            words = [ word for word in model.vocab ]
    
    word_vectors = np.array([model[w] for w in words])
    
    two_dim = PCA(random_state=0).fit_transform(word_vectors)[:,:2]

    data = []
    count = 0
    
    for i in range (len(user_input)):

                trace = go.Scatter(
                    x = two_dim[count:count+topn,0], 
                    y = two_dim[count:count+topn,1],  
                    text = words[count:count+topn],
                    name = user_input[i],
                    textposition = "top center",
                    textfont_size = 20,
                    mode = 'markers+text',
                    marker = {
                        'size': 10,
                        'opacity': 0.8,
                        'color': 'red'
                    }
       
                )
                
                data.append(trace)
                count = count+topn

    trace_input = go.Scatter(
                    x = two_dim[count:,0], 
                    y = two_dim[count:,1],  
                    text = words[count:],
                    name = 'input words',
                    textposition = "top center",
                    textfont_size = 20,
                    mode = 'markers+text',
                    marker = {
                        'size': 10,
                        'opacity': 1,
                        'color': 'black'
                    }
                    )


    data.append(trace_input)
    
    layout = go.Layout(
        margin = {'l': 0, 'r': 0, 'b': 0, 't': 0},
        showlegend=False,
        font = dict(
            family = " Courier New ",
            size = 15),
        autosize = False,
        width = 1000,
        height = 1000
        )


    plot_figure = go.Figure(data = data, layout = layout)
    plot_figure.show()
    

examined_numbers = 20
display_pca_scatterplot_2D(wv, user_input=list(password_df[:examined_numbers]['word']), words=list(password_df[:examined_numbers]['word']))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
